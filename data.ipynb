# %%
import yfinance as yf
import pandas as pd

# %%
data = yf.download("^VIX", period="1d")
data
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close   High    Low       Open Volume
# Ticker           ^VIX   ^VIX   ^VIX       ^VIX   ^VIX
# Date
# 2026-06-08  19.889999  20.35  19.74  20.290001      0

# %%
import pyfedwatch as fw
fomc_dates = fw.datareader.get_fomc_data_fed()
fomc_dates
# Out:
#                    Status                             Days
# FOMCDate
# 2021-01-27      Scheduled              January 26-27, 2021
# 2021-03-17      Scheduled                March 16-17, 2021
# 2021-04-28      Scheduled                April 27-28, 2021
# 2021-06-16      Scheduled                 June 15-16, 2021
# 2021-07-28      Scheduled                 July 27-28, 2021
# 2021-09-22      Scheduled            September 21-22, 2021
# 2021-11-03      Scheduled               November 2-3, 2021
# 2021-12-15      Scheduled             December 14-15, 2021
# 2022-01-26      Scheduled              January 25-26, 2022
# 2022-03-16      Scheduled                March 15-16, 2022
# 2022-05-04      Scheduled                    May 3-4, 2022
# 2022-06-15      Scheduled                 June 14-15, 2022
# 2022-07-27      Scheduled                 July 26-27, 2022
# 2022-09-21      Scheduled            September 20-21, 2022
# 2022-11-02      Scheduled               November 1-2, 2022
# ...

# %%
import concurrent.futures as cf
import pyfedwatch as fw

with cf.ThreadPoolExecutor(max_workers=1) as ex:
    future = ex.submit(fw.datareader.get_fomc_data)
    try:
        data = future.result(timeout=120)   # give it 2 minutes
        print(data)
    except cf.TimeoutError:
        print("Hung on a network request — see notes below.")
# Out:
# Hung on a network request — see notes below.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 import concurrent.futures as cf
#       2 import pyfedwatch as fw
# ----> 4 with cf.ThreadPoolExecutor(max_workers=1) as ex:
#       5     future = ex.submit(fw.datareader.get_fomc_data)
#       6     try:
#
# File ~/anaconda3/lib/python3.12/concurrent/futures/_base.py:647, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     646 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 647     self.shutdown(wait=True)
#     648     return False
#
# File ~/anaconda3/lib/python3.12/concurrent/futures/thread.py:238, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     236 if wait:
#     237     for t in self._threads:
# --> 238         t.join()
#
# File ~/anaconda3/lib/python3.12/threading.py:1147, in Thread.join(self, timeout)
# ...

# %%
print(yfinance.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(yfinance.__version__)
#
# NameError: name 'yfinance' is not defined
